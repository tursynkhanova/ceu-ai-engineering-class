# %% [markdown]
# # Short-Term Memory

# %%
from agents import Agent, Runner, SQLiteSession, trace
from setup import bedrock_tool
# Out:
# ✅ AWS credentials found
# ✅ OpenAI credentials found
# ✅ EXA credentials found

# %%
nutrition_agent = Agent(
    name="Nutrition Assistant",
    instructions="""
    You are a helpful assistant comparing how healthy different foods are.
    If you answer, give a list of how healthy the foods are with a score from 1 to 10. Order by: healtiest food comes first.

    Example:
    Q: Compare X and Y
    A: X is healtier as Y.
    1) X: 8/10 - Very healthy but high in fructose
    2) Y: 3/10 - High in sugar and fat
    """,
    model="litellm/bedrock/eu.amazon.nova-lite-v1:0",
)

# %% [markdown]
# ## No Memory

# %%
with trace("Compare without Memory") as t:
    result = await Runner.run(nutrition_agent, "Which is healthier, bananas or lollipop?")

print(f"Output: {result.final_output}")
print(f"\nTrace URL: https://platform.openai.com/logs/trace?trace_id={t.trace_id}")
# Out:
# Output: Certainly! Here is a comparison of the healthiness of bananas and lollipops:
#
# 1) **Bananas: 9/10** - Bananas are very healthy. They are rich in essential nutrients like potassium, vitamin B6, vitamin C, and dietary fiber. They also provide natural sugars and are beneficial for heart health, digestion, and muscle function.
#
# 2) **Lollipop: 1/10** - Lollipops are generally very unhealthy. They are high in sugar with little to no nutritional value. Consuming lollipops can contribute to tooth decay, weight gain, and spikes in blood sugar levels. They provide empty calories with no essential nutrients.
#
# Therefore, bananas are significantly healthier than lollipops.
#
# Trace URL: https://platform.openai.com/logs/trace?trace_id=trace_d38ed7f8902a4f5ba584e0e65c8b00ca

# %%
with trace("Add Apple - without Memory") as t:
    result = await Runner.run(nutrition_agent, "Add apples to the comparison")

print(f"Output: {result.final_output}")
print(f"\nTrace URL: https://platform.openai.com/logs/trace?trace_id={t.trace_id}")
# Out:
# Output: Let's compare apples to a few other foods in terms of their health scores.
#
# 1. **Apples: 9/10**
#    - Apples are high in dietary fiber, particularly soluble fiber which aids in digestion. They are also a good source of vitamin C and various antioxidants. However, they do contain natural sugars.
#
# 2. **Blueberries: 10/10**
#    - Blueberries are often considered a superfood due to their high levels of antioxidants, vitamin C, and fiber. They also support brain health and have anti-inflammatory properties.
#
# 3. **Spinach: 10/10**
#    - Spinach is packed with vitamins A, C, and K, as well as minerals like iron and calcium. It is low in calories and high in antioxidants, making it very healthy.
#
# 4. **Salmon: 9/10**
#    - Salmon is rich in omega-3 fatty acids, high-quality protein, and contains vitamins D and B12. It supports heart health and brain function but can be high in calories if consumed in large amounts.
#
# 5. **Oatmeal: 8/10**
#    - Oatmeal is a whole grain high in fiber, particularly beta-glucan, which helps lower cholesterol levels. It is also a good source of vitamins and minerals, but its health benefits can vary depending on added ingredients like sugar or honey.
#
# 6. **Nuts (e.g., almonds, walnuts): 9/10**
#    - Nuts are a good source of healthy fats, protein, fiber, and various vitamins and minerals. However, they are also high in calories, so portion control is important.
#
# So, ordered by healthiness:
#
# 1. **Blueberries: 10/10**
# 2. **Spinach: 10/10**
# 3. **Apples: 9/10**
# 4. **Salmon: 9/10**
# 5. **Nuts: 9/10**
# 6. **Oatmeal: 8/10**
#
# Trace URL: https://platform.openai.com/logs/trace?trace_id=trace_ffd68b60d5a640dc9c4c476be5192eca

# %% [markdown]
# ## Short Term Memory

# %%
session = SQLiteSession("conversation_history")

# %%
result = await Runner.run(
    nutrition_agent, "Which is healthier, bananas or lollipop?", session=session
)
print(result.final_output)
# Out:
# Let's compare the healthiness of bananas and lollipops with scores from 1 to 10:
#
# 1) Bananas: 9/10
#    - **Nutritional Benefits:** High in potassium, vitamin B6, vitamin C, and dietary fiber. They provide natural sugars, which can be a quick source of energy.
#    - **Drawbacks:** High in natural sugars, so they should be consumed in moderation if you are watching your sugar intake.
#
# 2) Lollipops: 2/10
#    - **Nutritional Benefits:** Essentially none. Lollipops are mostly sugar with artificial flavors and colors.
#    - **Drawbacks:** High in refined sugars, artificial ingredients, and no nutritional value. They can also be a choking hazard, especially for young children.
#
# So, bananas are significantly healthier than lollipops.
#
# 1) Bananas: 9/10
# 2) Lollipops: 2/10

# %%
with trace("Compare with Memory") as t:
    result = await Runner.run(
        nutrition_agent, "Add apples to the comparison", session=session
    )

print(f"Output: {result.final_output}")
print(f"\nTrace URL: https://platform.openai.com/logs/trace?trace_id={t.trace_id}")
# Out:
# Output: Let's add apples to the comparison and rank their healthiness from 1 to 10:
#
# 1) Bananas: 9/10
#    - **Nutritional Benefits:** High in potassium, vitamin B6, vitamin C, and dietary fiber. They provide natural sugars, which can be a quick source of energy.
#    - **Drawbacks:** High in natural sugars, so they should be consumed in moderation if you are watching your sugar intake.
#
# 2) Apples: 8/10
#    - **Nutritional Benefits:** Rich in dietary fiber, vitamin C, and various antioxidants. They can promote heart health and aid digestion.
#    - **Drawbacks:** Moderate in natural sugars, but the fiber helps mitigate the impact on blood sugar levels.
#
# 3) Lollipops: 2/10
#    - **Nutritional Benefits:** Essentially none. Lollipops are mostly sugar with artificial flavors and colors.
#    - **Drawbacks:** High in refined sugars, artificial ingredients, and no nutritional value. They can also be a choking hazard, especially for young children.
#
# So, in terms of healthiness:
#
# 1) Bananas: 9/10
# 2) Apples: 8/10
# 3) Lollipops: 2/10
#
# Trace URL: https://platform.openai.com/logs/trace?trace_id=trace_71c2bbbfab8a434aa8b351efc98b5269
