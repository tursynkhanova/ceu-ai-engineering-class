# %% [markdown]
# # MCP

# %%
from setup import bedrock_tool
import os
import chromadb
from agents import Agent, Runner, function_tool, trace
from agents.mcp import MCPServerStreamableHttp
# Out:
# ✅ AWS credentials found
# ✅ OpenAI credentials found
# ✅ EXA credentials found

# %% [markdown]
# Let's set up our RAG database connection:

# %%
chroma_client = chromadb.PersistentClient(path="../chroma")
nutrition_db = chroma_client.get_collection(name="nutrition_db")

# %%
# This is the same code as in the RAG notebook


@function_tool
def calorie_lookup_tool(query: str, max_results: int = 3) -> str:
    """
    Tool function for a RAG database to look up calorie information for specific food items, but not for meals.

    Args:
        query: The food item to look up.
        max_results: The maximum number of results to return.

    Returns:
        A string containing the nutrition information.
    """

    results = nutrition_db.query(query_texts=[query], n_results=max_results)

    if not results["documents"][0]:
        return f"No nutrition information found for: {query}"

    # Format results for the agent
    formatted_results = []
    for i, doc in enumerate(results["documents"][0]):
        metadata = results["metadatas"][0][i]
        food_item = metadata["food_item"].title()
        calories = metadata["calories_per_100g"]
        category = metadata["food_category"].title()

        formatted_results.append(
            f"{food_item} ({category}): {calories} calories per 100g"
        )

    return "Nutrition Information:\n" + "\n".join(formatted_results)

# %% [markdown]
# Integrate EXA Search as an MCP:

# %%
# Increased EXA timeout from 30 to 90 seconds since EXA can take longer than 30 seconds to respond when under heavy load
exa_search_mcp = MCPServerStreamableHttp(
    name="Exa Search MCP",
    params={
        "url": f"https://mcp.exa.ai/mcp?exaApiKey={os.environ.get('EXA_API_KEY')}",
        "timeout": 90,
    },
    client_session_timeout_seconds=90,
    cache_tools_list=True,
    max_retry_attempts=1,
)

await exa_search_mcp.connect()

calorie_agent_with_search = Agent(
    name="Nutrition Assistant",
    instructions="""
    * You are a helpful nutrition assistant giving out calorie information.
    * You give concise answers.
    * You follow this workflow:
        0) First, use the calorie_lookup_tool to get the calorie information of the ingredients. But only use the result if it's explicitly for the food requested in the query.
        1) If you couldn't find the exact match for the food or you need to look up the ingredients, search the EXA web to figure out the exact ingredients of the meal.
        Even if you have the calories in the web search response, you should still use the calorie_lookup_tool to get the calorie
        information of the ingredients to make sure the information you provide is consistent.
        2) Then, if necessary, use the calorie_lookup_tool to get the calorie information of the ingredients.
    * Even if you know the recipe of the meal, always use Exa Search to find the exact recipe and ingredients.
    * Once you know the ingredients, use the calorie_lookup_tool to get the calorie information of the individual ingredients.
    * If the query is about the meal, in your final output give a list of ingredients with their quantities and calories for a single serving. Also display the total calories.
    * Don't use the calorie_lookup_tool more than 10 times.
    * Respond with Markdown formatting, and use bullet points and where appropriate. Don't use tables
    """,
    model="litellm/bedrock/eu.amazon.nova-lite-v1:0",
    tools=[bedrock_tool(calorie_lookup_tool.__dict__)],
    mcp_servers=[exa_search_mcp],
)

# %% [markdown]
# Reference query - shouldn't use ExaSearch:

# %%
with trace("Nutrition Assistant with MCP - Only uses calorie_lookup_tool") as t:
    result = await Runner.run(
        calorie_agent_with_search,
        "How many calories are in a full english breakfast? Also give calories per 100g",
    )

print(f"# Output:\n\n{result.final_output}")
print(f"\nTrace URL: https://platform.openai.com/logs/trace?trace_id={t.trace_id}")
# Out:
# # Output:
#
# Based on the ingredients and their respective calorie information, here's a breakdown of a full English breakfast:
#
# - **Sausages**: 315 calories per 100g
# - **Bacon**: 107 calories per 100g
# - **Mushrooms**: 22 calories per 100g
# - **Tomatoes**: 18 calories per 100g
# - **Black Pudding**: 253 calories per 100g
# - **Egg**: 185 calories per 100g
# - **Bread**: 361 calories per 100g
# - **Baked Beans**: 94 calories per 100g
#
# For a single serving of a full English breakfast, let's assume the following quantities:
#
# - **Sausages**: 2 (50g each) = 315 calories
# - **Bacon**: 2-3 rashers (50g each) = 107-160.5 calories
# - **Mushrooms**: 2 (50g each) = 44 calories
# - **Tomatoes**: 1-2 (50g each) = 18-36 calories
# - **Black Pudding**: 1 slice (50g) = 126.5 calories
# - **Egg**: 1 (50g) = 92.5 calories
# - **Bread**: 1 slice (25g) = 90.25 calories
# - **Baked Beans**: 1/2 cup (50g) = 47 calories
#
# **Total Calories**: 1103.25 calories
#
# This is an estimate based on the given quantities and calorie information per 100g. The actual calorie count may vary depending on the specific brands and portion sizes used.
#
# Trace URL: https://platform.openai.com/logs/trace?trace_id=trace_ca8164f99be9481eaa8cac9d5d2e6fe9

# %%
with trace("Nutrition Assistant with MCP ") as t:
    result = await Runner.run(
        calorie_agent_with_search, "How many calories are in an english breakfast?"
    )

print(f"# Output:\n\n{result.final_output}")
print(f"\nTrace URL: https://platform.openai.com/logs/trace?trace_id={t.trace_id}")
# Out:
# # Output:
#
# Here are the ingredients of a Full English Breakfast with their calories per serving:
#
# - **2 eggs (fried, scrambled, or poached)**: 140 calories (based on average egg size)
# - **2-3 slices of turkey bacon (preferably British-style back bacon)**: 214-321 calories (based on 107 calories per 100g)
# - **2 sausages (Cumberland or your favorite type)**: 630 calories (based on 315 calories per 100g)
# - **1 tomato, halved**: 9 calories (based on 18 calories per 100g)
# - **1/2 cup baked beans (British-style)**: 47 calories (based on 94 calories per 100g)
# - **1-2 slices of black pudding (optional)**: 253-506 calories (based on 253 calories per 100g)
# - **4-5 mushrooms, sliced**: 11-16.5 calories (based on 22 calories per 100g)
# - **2 slices of toast or fried bread**: 284 calories (based on 361 calories per 100g)
# - **1 tablespoon butter (for frying)**: 72 calories (based on 720 calories per 100g)
#
# **Total calories for a Full English Breakfast**: 1574-1924 calories
#
# Please note that these are approximate values based on the ingredients and their calorie content per 100g. The actual calorie content may vary depending on the specific brands and portion sizes used.
#
# Trace URL: https://platform.openai.com/logs/trace?trace_id=trace_b9df2b78e3374d81ae5aea3a5a94ac67
